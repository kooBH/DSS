# %%
import torch
import torch.nn as nn
import numpy as np

import matplotlib.pyplot as plt   
import IPython.display as ipd

# %%
path = '/home/data2/kbh/LRS3/test_embedding/0Fi83BHQsMA/00002.npz'
path = '/home/data2/kbh/LRS3/test_crop/0Fi83BHQsMA/00002.npz'

# %%
x = np.load(path)
for k in x.files:
    print(k)
x["data"].shape
# Out:
# data
# (41, 112, 112)

# %%
plt.imshow(x["data"][35], interpolation='nearest',cmap='gray')
plt.show()

# %%
# Out:
# (1, 41, 512)
