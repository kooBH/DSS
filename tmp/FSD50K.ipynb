# %%
import pandas as pd
import os
from glob import glob

# %%
FSD50k_meta_root = "/home/data2/kbh/FSD50K/FSD50K.metadata/collection/"
csv_eval = pd.read_csv(os.path.join(FSD50k_meta_root,"collection_dev.csv"))
csv_eval.head()
# Out:
#    fname           labels      mids
# 0  64760  Electric_guitar  /m/02sgy
# 1  16399  Electric_guitar  /m/02sgy
# 2  16401  Electric_guitar  /m/02sgy
# 3  16402  Electric_guitar  /m/02sgy
# 4  16404  Electric_guitar  /m/02sgy

# %%
for i in range(len(csv_eval.index)) : 
    if type(csv_eval.iloc[i,1]) is not str : 
        continue
    if csv_eval.iloc[i,1] in "Male_speech_and_man_speaking":
        print(csv_eval.iloc[i])
    if csv_eval.iloc[i,1] in "Female_speech_and_woman_speaking":
        print(csv_eval.iloc[i])
# Out:
# fname                           236544
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 1995, dtype: object
# fname                           429037
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 1996, dtype: object
# fname                           236553
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 1998, dtype: object
# fname                           236555
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 1999, dtype: object
# fname                           236556
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 2000, dtype: object
# fname                           236557
# labels    Male_speech_and_man_speaking
# mids                         /m/05zppz
# Name: 2001, dtype: object
# fname                           236558
# labels    Male_speech_and_man_speaking
# ...

# %%
csv_eval.iloc[0,1]
# Out:
# 'Electric_guitar'
